# %% [markdown]
# # Data Structures
# + Introduces Python’s built-in data structures
#   + lists,
#   + dictionaries,
#   + tuples,
#   + sets
# + And their use in handling structured/unstructured data.
